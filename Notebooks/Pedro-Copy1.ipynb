# %% [markdown]
# # Pedro - Short Queeze Predictor

# %%
# Initial imports
import pandas as pd
from pathlib import Path

# %%
# Read the 2023_Short-Interest-Data.csv file from the Resources folder into a Pandas DataFrame
companies_df = pd.read_csv(Path("Resources/2023_Short-Data.csv"))

# Review the DataFrame
companies_df.head()
# Out:
#                              Company Name Symbol  Short % of Float  Price  \
# 0               Allogene Therapeutics Inc   ALLO             41.77   7.99
# 1                    Sonic Automotive Inc    SAH             30.26  49.60
# 2                            Safehold Inc   SAFE             18.80  33.67
# 3                Root Inc. - common stock   ROOT             21.17   5.26
# 4  Relay Therapeutics Inc. - Common Stock   RLAY             19.98  20.42
#
#      Market Cap Exchange              Sector                         Industry  \
# 0  1.130905e+09      NAS          Healthcare                    Biotechnology
# 1  1.466672e+09       NY   Consumer Cyclical         Auto & Truck Dealerships
# 2  1.793264e+09       NY         Real Estate               REIT - Diversified
# 3  4.570414e+08      NAS  Financial Services  Insurance - Property & Casualty
# 4  1.846581e+09      NAS          Healthcare                    Biotechnology
#
#   Record Date
# 0  2023-01-11
# 1  2023-01-11
# 2  2023-01-11
# 3  2023-01-11
# 4  2023-01-11

# %%
# Filter the DataFrame for rows with 'Record Date' equal to '2023-01-25'
filtered_df = companies_df[companies_df['Record Date'] == '2023-01-25']

# Display the filtered DataFrame
filtered_df
# Out:
#                                  Company Name Symbol  Short % of Float  \
# 78                        Cowen Inc - Class A   COWN             32.82
# 79              Credit Acceptance Corporation   CACC             17.53
# 80                       Celsius Holdings Inc   CELH             23.73
# 81                  Canopy Growth Corporation    CGC             17.59
# 82                          Chewy Inc Class A   CHWY             24.67
# ..                                        ...    ...               ...
# 149         Nikola Corporation - Common Stock   NKLA             29.11
# 150          Sunnova Energy International Inc   NOVA             22.89
# 151  Opendoor Technologies Inc - Common Stock   OPEN             19.08
# 152               Penske Automotive Group Inc    PAG             20.41
# 153                        Petmed Express Inc   PETS             19.92
#
#       Price    Market Cap Exchange              Sector  \
# 78    38.89  1.044974e+09      NAS  Financial Services
# 79   484.23  8.091483e+09      NAS  Financial Services
# 80    96.41  6.956946e+09      NAS  Consumer Defensive
# 81     2.27  8.693646e+08      NAS          Healthcare
# 82    45.16  4.706124e+09       NY   Consumer Cyclical
# ..      ...           ...      ...                 ...
# 149    2.42  9.531170e+08      NAS   Consumer Cyclical
# 150   17.25  1.931482e+09       NY          Technology
# 151    2.04  1.178488e+09      NAS         Real Estate
# 152  139.20  1.125154e+10       NY   Consumer Cyclical
# 153   19.87  4.027649e+08      NAS          Healthcare
#
#                                      Industry Record Date
# 78                            Capital Markets  2023-01-25
# 79                            Credit Services  2023-01-25
# 80                  Beverages - Non-Alcoholic  2023-01-25
# 81   Drug Manufacturers - Specialty & Generic  2023-01-25
# 82                            Internet Retail  2023-01-25
# ..                                        ...         ...
# 149                        Auto Manufacturers  2023-01-25
# 150                                     Solar  2023-01-25
# 151                      Real Estate Services  2023-01-25
# 152                  Auto & Truck Dealerships  2023-01-25
# 153                  Pharmaceutical Retailers  2023-01-25
#
# [76 rows x 9 columns]

# %%
# Using len() function
row_count = len(filtered_df)
print("Number of rows:", row_count)
# Out:
# Number of rows: 76

# %%
# Review the data types associated with the columns
filtered_df.dtypes
# Out:
# Company Name         object
# Symbol               object
# Short % of Float    float64
# Price               float64
# Market Cap          float64
# Exchange             object
# Sector               object
# Industry             object
# Record Date          object
# dtype: object
